# %%
# Modified version for training YOLOv7-tiny on turn_signal_dataset using compressed dataset

# Step 1: 從 Google Drive 複製壓縮的資料集檔案
# !cp /content/drive/MyDrive/turn_signal_dataset/images.zip .
# !cp /content/drive/MyDrive/turn_signal_dataset/labels.zip .

# Step 2: 解壓縮圖片和標籤
# !unzip ./images.zip -d .
# !unzip ./labels.zip -d .

# Step 3: 從 Google Drive 複製並解壓縮 yolov7-main.zip
# !cp /content/drive/MyDrive/yolov7-main.zip .
# !unzip ./yolov7-main.zip -d .

# Step 4: 切換工作目錄到 yolov7-main
# %cd /content/yolov7-main

# Step 5: 從 Google Drive 複製預訓練權重 yolov7-tiny.pt
# !cp /content/drive/MyDrive/yolov7-tiny.pt .

# Step 6: 執行訓練腳本，使用現有的 data.yaml
# 注意：請確認 data.yaml 中的路徑與解壓後的圖片和標籤位置一致
# !python train.py --weights yolov7-tiny.pt --cfg cfg/training/yolov7-tiny.yaml --data /content/drive/MyDrive/turn_signal_dataset/data.yaml --epochs 50 --batch-size 8 --img 640 640
# Out:
# Archive:  ./images.zip
# replace ./images/test/car10_74.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./images/test/car10_74.jpg
#   inflating: ./images/test/car10_75.jpg
#   inflating: ./images/test/car10_76.jpg
#   inflating: ./images/test/car10_77.jpg
#   inflating: ./images/test/car10_78.jpg
#   inflating: ./images/test/car10_79.jpg
#   inflating: ./images/test/car10_80.jpg
#   inflating: ./images/test/car10_81.jpg
#   inflating: ./images/test/car10_82.jpg
#   inflating: ./images/test/car10_83.jpg
#   inflating: ./images/test/car10_84.jpg
#   inflating: ./images/test/car10_85.jpg
#   inflating: ./images/test/car10_86.jpg
#   inflating: ./images/test/car10_87.jpg
#   inflating: ./images/test/car10_88.jpg
#   inflating: ./images/test/car1_12.jpg
#   inflating: ./images/test/car1_13.jpg
#   inflating: ./images/test/car1_14.jpg
#   inflating: ./images/test/car1_15.jpg
#   inflating: ./images/test/car1_16.jpg
#   inflating: ./images/test/car1_17.jpg
# ...

# %%
# %cd /content/yolov7-main
# !cp /content/drive/MyDrive/yolov7-tiny.pt .
# !python train.py --weights yolov7-tiny.pt --cfg cfg/training/yolov7-tiny.yaml --data /content/drive/MyDrive/turn_signal_dataset/data.yaml --epochs 50 --batch-size 8 --img 640 640
# Out:
# /content/yolov7-main
# 2025-06-09 04:30:06.575092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749443406.607720    7847 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749443406.619000    7847 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-09 04:30:06.650327: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !ls /content/images
# !ls /content/labels
# Out:
# test  train  val
# test  train  val

# %%
# !unzip -o ./images.zip -d /content
# !unzip -o ./labels.zip -d /content
# Out:
# Archive:  ./images.zip
#    creating: /content/images/
#    creating: /content/images/test/
#   inflating: /content/images/test/car10_74.jpg
#   inflating: /content/images/test/car10_75.jpg
#   inflating: /content/images/test/car10_76.jpg
#   inflating: /content/images/test/car10_77.jpg
#   inflating: /content/images/test/car10_78.jpg
#   inflating: /content/images/test/car10_79.jpg
#   inflating: /content/images/test/car10_80.jpg
#   inflating: /content/images/test/car10_81.jpg
#   inflating: /content/images/test/car10_82.jpg
#   inflating: /content/images/test/car10_83.jpg
#   inflating: /content/images/test/car10_84.jpg
#   inflating: /content/images/test/car10_85.jpg
#   inflating: /content/images/test/car10_86.jpg
#   inflating: /content/images/test/car10_87.jpg
#   inflating: /content/images/test/car10_88.jpg
#   inflating: /content/images/test/car1_12.jpg
#   inflating: /content/images/test/car1_13.jpg
#   inflating: /content/images/test/car1_14.jpg
# ...

# %%
# !ls /content/images
# !ls /content/labels
# Out:
# ls: cannot access '/content/images': No such file or directory
# ls: cannot access '/content/labels': No such file or directory

# %%
# Modified version for training YOLOv7-tiny on turn_signal_dataset

# Step 1: Copy and unzip the yolov7-main.zip from Google Drive
# !cp /content/drive/MyDrive/yolov7-main.zip .
# !unzip ./yolov7-main.zip -d .

# Step 2: Change directory to yolov7-main
# %cd /content/yolov7-main

# Step 3: Copy the pre-trained weights yolov7-tiny.pt from Google Drive
# !cp /content/drive/MyDrive/yolov7-tiny.pt .

# Step 4: Run the training script with the existing data.yaml
# !python train.py --weights yolov7-tiny.pt --cfg cfg/training/yolov7-tiny.yaml --data /content/drive/MyDrive/turn_signal_dataset/data.yaml --epochs 30 --batch-size 8 --img 640 640
# Out:
# Archive:  ./yolov7-main.zip
# a207844b1ce82d204ab36d87d496728d3d2348e7
# replace ./yolov7-main/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./yolov7-main/.gitignore
#   inflating: ./yolov7-main/LICENSE.md
#   inflating: ./yolov7-main/README.md
#   inflating: ./yolov7-main/cfg/baseline/r50-csp.yaml
#   inflating: ./yolov7-main/cfg/baseline/x50-csp.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-csp-x.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-csp.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-d6.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-e6.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-p6.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolor-w6.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolov3-spp.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolov3.yaml
#   inflating: ./yolov7-main/cfg/baseline/yolov4-csp.yaml
#   inflating: ./yolov7-main/cfg/deploy/yolov7-d6.yaml
#   inflating: ./yolov7-main/cfg/deploy/yolov7-e6.yaml
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fafd88ec-5656-45c6-940a-6c4317ca103c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fafd88ec-5656-45c6-940a-6c4317ca103c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
